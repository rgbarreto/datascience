# %%
import pandas as pd

# %%
notas = pd.read_csv("https://raw.githubusercontent.com/alura-cursos/data-science-analise-exploratoria/main/Aula_0/ml-latest-small/ratings.csv")
notas
# Out:
#         userId  movieId  rating   timestamp
# 0            1        1     4.0   964982703
# 1            1        3     4.0   964981247
# 2            1        6     4.0   964982224
# 3            1       47     5.0   964983815
# 4            1       50     5.0   964982931
# ...        ...      ...     ...         ...
# 100831     610   166534     4.0  1493848402
# 100832     610   168248     5.0  1493850091
# 100833     610   168250     5.0  1494273047
# 100834     610   168252     5.0  1493846352
# 100835     610   170875     3.0  1493846415
#
# [100836 rows x 4 columns]

# %%
notas.shape
# Out:
# (100836, 4)

# %%
notas.columns
# Out:
# Index(['userId', 'movieId', 'rating', 'timestamp'], dtype='object')

# %%
notas.columns = ["usuarioId", "filmeId", "nota", "momento"]
notas.head()
# Out:
#    usuarioId  filmeId  nota    momento
# 0          1        1   4.0  964982703
# 1          1        3   4.0  964981247
# 2          1        6   4.0  964982224
# 3          1       47   5.0  964983815
# 4          1       50   5.0  964982931

# %%
notas["nota"]
# Out:
# 0         4.0
# 1         4.0
# 2         4.0
# 3         5.0
# 4         5.0
#          ...
# 100831    4.0
# 100832    5.0
# 100833    5.0
# 100834    5.0
# 100835    3.0
# Name: nota, Length: 100836, dtype: float64

# %%
notas["nota"].unique()
# Out:
# array([4. , 5. , 3. , 2. , 1. , 4.5, 3.5, 2.5, 0.5, 1.5])

# %%
notas["nota"].value_counts()
# Out:
# nota
# 4.0    26818
# 3.0    20047
# 5.0    13211
# 3.5    13136
# 4.5     8551
# 2.0     7551
# 2.5     5550
# 1.0     2811
# 1.5     1791
# 0.5     1370
# Name: count, dtype: int64

# %%
notas["nota"].mean()
# Out:
# np.float64(3.501556983616962)

# %%
pd.read_csv('/content/ratings.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-1596201650.py in <cell line: 0>()
# ----> 1 pd.read_csv('/content/ratings.csv')
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
#    1025
# ...

# %%
notas["nota"].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
notas["nota"].median()
# Out:
# 3.5

# %%
mediana = notas["nota"].median()
media = notas["nota"].mean()
print(f"Mediana é:{mediana}")
print(f"Media é: {media}")
# Out:
# Mediana é:3.5
# Media é: 3.501556983616962

# %%
notas["nota"].describe()
# Out:
# count    100836.000000
# mean          3.501557
# std           1.042529
# min           0.500000
# 25%           3.000000
# 50%           3.500000
# 75%           4.000000
# max           5.000000
# Name: nota, dtype: float64

# %%
import seaborn as sns
sns.boxplot(notas["nota"])
# Out:
# <Axes: ylabel='nota'>

# %%
# Criando um dataFrame simples
dados = {'Nome': ['Maria','Ana', 'Daniel'],
          'Idade': [25,30,35],
            'Salario': [5000,6000, 8000]}
df= pd.DataFrame(dados)
df
# Out:
#      Nome  Idade  Salario
# 0   Maria     25     5000
# 1     Ana     30     6000
# 2  Daniel     35     8000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Nome     3 non-null      object
#  1   Idade    3 non-null      int64
#  2   Salario  3 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 204.0+ bytes

# %%
df['Salario'].mean()
# ou df.Salario.mean()
# Out:
# np.float64(6333.333333333333)

# %%
import pandas as pd

# Criando um Series simples
idades = pd.Series([45, 30, 45, 40, 25])
idades
# Out:
# 0    45
# 1    30
# 2    45
# 3    40
# 4    25
# dtype: int64

# %%
idades.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
idades.sort_values()
# Out:
# 4    25
# 1    30
# 3    40
# 0    45
# 2    45
# dtype: int64

# %%
filmes = pd.read_csv("https://raw.githubusercontent.com/alura-cursos/data-science-analise-exploratoria/main/Aula_0/ml-latest-small/movies.csv")
filmes.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
notas.query("filmeId==1").mean()
# Out:
# usuarioId    3.065302e+02
# filmeId      1.000000e+00
# nota         3.920930e+00
# momento      1.129835e+09
# dtype: float64

# %%
notas.query("filmeId==2")["nota"].mean()
# Out:
# np.float64(3.4318181818181817)

# %%
notas.groupby("filmeId")["nota"].mean()
# Out:
# filmeId
# 1         3.920930
# 2         3.431818
# 3         3.259615
# 4         2.357143
# 5         3.071429
#             ...
# 193581    4.000000
# 193583    3.500000
# 193585    3.500000
# 193587    3.500000
# 193609    4.000000
# Name: nota, Length: 9724, dtype: float64

# %%
medias_por_filme = notas.groupby("filmeId")["nota"].mean()
medias_por_filme.head()
# Out:
# filmeId
# 1    3.920930
# 2    3.431818
# 3    3.259615
# 4    2.357143
# 5    3.071429
# Name: nota, dtype: float64

# %%
medias_por_filme.plot(kind ="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
vendas =pd.read_csv("https://cdn3.gnarususercontent.com.br/3675-data-science-analise-exploratoria/Projeto/Base_Atividades/serenatto_2sem_2023.csv")

# %%
import pandas as pd
vendas = pd.read_csv("https://cdn3.gnarususercontent.com.br/3675-data-science-analise-exploratoria/Projeto/Base_Atividades/serenatto_2sem_2023.csv")
somatorio_vendas = vendas.query("produto == 'Ratatouille'").valor.sum()
frequencia_metodo_pagamento = vendas.query("produto == 'Ratatouille'").metodo_pagamento.value_counts()
print(f"A vendas de Ratatouille foram de R${somatorio_vendas}")
print(f"\nOs métodos de pagamento utilizados foram:\n{frequencia_metodo_pagamento}")
# Out:
# A vendas de Ratatouille foram de R$323.0
#
# Os métodos de pagamento utilizados foram:
# metodo_pagamento
# PIX                  13
# Cartão de Débito     10
# Dinheiro              9
# Cartão de Crédito     6
# Name: count, dtype: int64

# %%
vendas.query('produto == "Tiramisù" ').head()
# Out:
#       id        data   produto  valor   metodo_pagamento
# 1   2721  2023-07-02  Tiramisù   10.0   Cartão de Débito
# 2   2722  2023-07-02  Tiramisù   10.0  Cartão de Crédito
# 15  2735  2023-07-06  Tiramisù   10.0  Cartão de Crédito
# 30  2750  2023-07-07  Tiramisù   10.0   Cartão de Débito
# 31  2751  2023-07-07  Tiramisù   10.0   Cartão de Débito

# %%
vendas.query('valor > 10 and metodo_pagamento != "Dinheiro" ')
# Out:
#        id        data           produto  valor   metodo_pagamento
# 0    2720  2023-07-01  Risoto de Funghi   13.0   Cartão de Débito
# 5    2725  2023-07-03    Salada Niçoise   11.0                PIX
# 7    2727  2023-07-04           Lasanha   11.5                PIX
# 8    2728  2023-07-04           Gnocchi   10.5                PIX
# 18   2738  2023-07-06    Salada Niçoise   11.0   Cartão de Débito
# ..    ...         ...               ...    ...                ...
# 822  3542  2023-12-26           Lasanha   11.5   Cartão de Débito
# 830  3550  2023-12-28           Lasanha   11.5                PIX
# 831  3551  2023-12-28           Lasanha   11.5                PIX
# 836  3556  2023-12-28    Salada Niçoise   11.0  Cartão de Crédito
# 854  3574  2023-12-31           Gnocchi   10.5   Cartão de Débito
#
# [158 rows x 5 columns]

# %%
# Definindo uma variável externa
produtos = ['Café au lait', 'Espresso', 'Cappuccino']

vendas.query('produto in @produtos and metodo_pagamento == "PIX" ')
# Out:
#        id        data       produto  valor metodo_pagamento
# 9    2729  2023-07-04      Espresso    2.5              PIX
# 42   2762  2023-07-10  Café au lait    4.0              PIX
# 64   2784  2023-07-14      Espresso    2.5              PIX
# 76   2796  2023-07-16  Café au lait    4.0              PIX
# 77   2797  2023-07-16  Café au lait    4.0              PIX
# 130  2850  2023-07-29  Café au lait    4.0              PIX
# 174  2894  2023-08-08  Café au lait    4.0              PIX
# 185  2905  2023-08-11    Cappuccino    5.5              PIX
# 251  2971  2023-08-27      Espresso    2.5              PIX
# 278  2998  2023-08-31    Cappuccino    5.5              PIX
# 335  3055  2023-09-14      Espresso    2.5              PIX
# 362  3082  2023-09-19    Cappuccino    5.5              PIX
# 380  3100  2023-09-22  Café au lait    4.0              PIX
# 391  3111  2023-09-24      Espresso    2.5              PIX
# 404  3124  2023-09-27    Cappuccino    5.5              PIX
# ...

# %%
sns.boxplot(medias_por_filme)
# Out:
# <Axes: ylabel='nota'>

# %%
medias_por_filme.describe()
# Out:
# count    9724.000000
# mean        3.262448
# std         0.869874
# min         0.500000
# 25%         2.800000
# 50%         3.416667
# 75%         3.911765
# max         5.000000
# Name: nota, dtype: float64

# %%
import matplotlib.pyplot as plt

sns.displot(medias_por_filme,kde= "true")

plt.title("Historgrama das medias dos filmes")
# Out:
# Text(0.5, 1.0, 'Historgrama das medias dos filmes')
